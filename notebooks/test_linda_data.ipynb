# %%
import numpy as np

# %%
path = '/pscratch/sd/l/lindajin/DH_profile_kSZ_WL/data/'
filename = 'mean_DeltaSigma_total_profiles_arcmin_snap74_nd_2_n_62_seventh_gen.npz'

# %%
data = np.load(path + filename)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = np.load(path + filename)
#
# File ~/.conda/envs/fgas-ml/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# PermissionError: [Errno 13] Permission denied: '/pscratch/sd/l/lindajin/DH_profile_kSZ_WL/data/mean_DeltaSigma_total_profiles_arcmin_snap74_nd_2_n_62_seventh_gen.npz'
