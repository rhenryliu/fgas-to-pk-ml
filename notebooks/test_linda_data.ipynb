# %%
import numpy as np

# %%
path = '/pscratch/sd/l/lindajin/DH_profile_kSZ_WL/data/'
filename = 'mean_DeltaSigma_total_profiles_arcmin_snap74_nd_2_n_62_seventh_gen.npz'

path = '/pscratch/sd/l/lindajin/CAMELS/IllustrisTNG/L50n512_SB35/SB35_1/data/'
filename = 'Profiles_tau-CAP_total-DSigma_ionized_gas-DSigma_snap74.npz'

# %%
data = np.load(path + filename)

# %%
with np.load(path + filename) as data:
    
    # 2. List all the array names stored inside the file
    print("Stored arrays:", data.files)
    
    # 3. Load a specific array by using its key name
    # (By default, NumPy names them 'arr_0', 'arr_1', etc. if not specified)
    for array in data.files:
        print(f"Array name: {array}, shape: {data[array].shape}, dtype: {data[array].dtype}")
        print(data[array])
        
    # my_array = data['arr_0']
    
    # print(my_array)
    # print(data.fil)
# Out:
# Stored arrays: ['prof0_tau_CAP_xy', 'prof1_total_DSigma_arcmin2_xy', 'prof1_total_DSigma_kpch2_xy', 'prof2_ionized_gas_DSigma_arcmin2_xy', 'prof2_ionized_gas_DSigma_kpch2_xy', 'prof0_tau_CAP_xz', 'prof1_total_DSigma_arcmin2_xz', 'prof1_total_DSigma_kpch2_xz', 'prof2_ionized_gas_DSigma_arcmin2_xz', 'prof2_ionized_gas_DSigma_kpch2_xz', 'prof0_tau_CAP_yz', 'prof1_total_DSigma_arcmin2_yz', 'prof1_total_DSigma_kpch2_yz', 'prof2_ionized_gas_DSigma_arcmin2_yz', 'prof2_ionized_gas_DSigma_kpch2_yz', 'r0_arcmin', 'r0_to_mpch', 'r12_to_arcmin', 'r12_mpch', 'halo_masses', 'stellar_masses', 'number_density', 'nPixels01', 'pixelSize01', 'methods01', 'units01', 'fb', 'HubbleParam', 'redshift']
# Array name: prof0_tau_CAP_xy, shape: (20, 300), dtype: float64
# [[ 1.03406572e+00  1.41669393e+00  1.09737693e+00 ...  4.92715592e-02
#    3.83148464e-02  5.93497743e-02]
#  [ 3.45155707e+00  4.51259939e+00  4.05422745e+00 ...  9.14152330e-02
#    1.57219273e-01  1.62616528e-01]
# ...

# %%
fileName2 = "/pscratch/sd/r/rhliu/projects/fgas-to-pk-ml/datasets/CAMELS-IllustrisTNG-L50n512-SB35/snap074_z0.47/src-lindajin/fgas_spk__CAMELS-IllustrisTNG-L50n512-SB35__snap074_z0.47__src-lindajin__rank-m500__20260702.npz"

file2 = np.load(fileName2)

with np.load(fileName2) as data:
    
    # 2. List all the array names stored inside the file
    print("Stored arrays:", data.files)
    
    # 3. Load a specific array by using its key name
    # (By default, NumPy names them 'arr_0', 'arr_1', etc. if not specified)
    for array in data.files:
        print(f"Array name: {array}, shape: {data[array].shape}, dtype: {data[array].dtype}")
        print(data[array])
        
    # my_array = data['arr_0']
    
    # print(my_array)
    # print(data.fil)
# Out:
# Stored arrays: ['__meta__', 'radii_mpch', 'number_densities', 'fgas', 'fgas_std', 'k', 'suppression', 'sim_ids', 'mean_halo_mass', 'camels_params', 'camels_param_names']
# Array name: __meta__, shape: (), dtype: <U2331
# ...
